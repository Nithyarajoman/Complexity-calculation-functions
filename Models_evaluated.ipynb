# %% [markdown]
# <a href="https://colab.research.google.com/github/Nithyarajoman/Complexity-calculation-functions/blob/main/Models_evaluated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models

# %%
# MAC CALCULATION
# Function to calculate return MAC from each layer
def mac_each_layer(l):
    o_shape, i_shape, strides, ks, filters = ['', '', ''], ['', '', ''], [1, 1], [0, 0], [0, 0]        
    macc = 0
    
    if ('Dense' in str(l)):
        i_shape = l.input.shape[1:4].as_list()[0]
        o_shape = l.output.shape[1:4].as_list()
        macc = (o_shape[0] * i_shape)

    
    if ('Conv2D ' in str(l) and 'DepthwiseConv2D' not in str(l) and 'SeparableConv2D' not in str(l)):
        strides = l.strides
        ks = l.kernel_size
        filters = l.filters
        i_shape = l.input.get_shape()[1:4].as_list()
        o_shape = l.output.get_shape()[1:4].as_list()

        if (filters == None):
            filters = i_shape[2]

        macc = ((filters * ks[0] * ks[1] * i_shape[2]) * (
                (i_shape[0] / strides[0]) * (i_shape[1] / strides[1])))

    if ('Conv2D ' in str(l) and 'DepthwiseConv2D' in str(l) and 'SeparableConv2D' not in str(l)):
        strides = l.strides
        ks = l.kernel_size
        filters = l.filters
        i_shape = l.input.get_shape()[1:4].as_list()
        o_shape = l.output.get_shape()[1:4].as_list()

        if (filters == None):
            filters = i_shape[2]

        macc = ((ks[0] * ks[1] * i_shape[2]) * ((i_shape[0] / strides[0]) * (i_shape[1] / strides[1])))

    return macc

# Function to pass layers to the calculating function and to get the macc of each layer
def MAC_summary(model):
  print('%25s | %6s' % ('Layer Name', 'MACs'))
  print('*' * 100)
  t_macc = 0

  for l in model.layers:
    if (type(l) in [models.Sequential, keras.Model]):
      for ib_layer in l.layers:
        mac_obtained = mac_each_layer(ib_layer)
        print('%25s(%5s) | %5.4f' % (
                l.name,ib_layer.name, mac_obtained ))
        t_macc += mac_obtained  

    else:
      mac_obtained = mac_each_layer(l)
      print('%25s | %5.4f' % (
                l.name, mac_obtained ))
      
    t_macc += mac_obtained
  print('\nTotal MACs operations in the complete model: %10.8f\n' % (t_macc))
  return

# %%
# EFFECTIVE DATA COMMUNICATION

# Function to print the effective data communicated 
def data_summary(model):

  # Function to add communicated data to the metrics
  def add_metrics(m2):
    "Annotates recursiverly a (non-compiled) model with metrics that calculate probability of non-zero activity"
    prefix_name = m2.name + "_"
    for ll in m2.layers:
        if is_hier_layer(ll):
            add_metrics(ll)
        else:
            my_metric = tf.reduce_sum( tf.math.count_nonzero(ll.output, dtype=tf.int32) / tf.size( ll.output)  )
            name=prefix_name + ll.name
            m2.add_metric(my_metric, name=name)
    return

  # Function to check if a layer is model or not
  def is_hier_layer(layer):
      "Finds if layer is actually a model instead of a single layer"
      return type(layer) in [models.Sequential, keras.Model]

  # Clone the model. Note that it is not compiled!
  m2 = keras.models.clone_model(model)
  add_metrics(m2)
  
  # Compiling the cloned model and take the inference
  m2.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

  aux = m2.evaluate(x_test[0:1000], y_test[0:1000]) 
  
  print('%40s | %20s' % ('Metrics and Layer Name', 'Effective data communicated'))
  print("*" * 150)
  for l in m2.metrics:
    print('%40s | %5.4f' % (l.name, l.result().numpy()))
  return

# %%
# ImageNet classification dataset for Resnet18 and ResNet50
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data() #Size is (, 32,32,3)

# %%
# Calculations for Resnet18 CNN model
# !pip install image-classifiers
from tensorflow.keras.applications import imagenet_utils
from classification_models.keras import Classifiers

ResNet18, preprocess_input = Classifiers.get('resnet18')
model_ResNet18 = ResNet18(include_top=False,
                        input_tensor=None,
                        input_shape=(
                            32, 32, 3),
                        pooling=None)
MAC_summary(model_ResNet18)
data_summary(model_ResNet18)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: image-classifiers in /usr/local/lib/python3.8/dist-packages (1.0.0)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.8/dist-packages (from image-classifiers) (1.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.8/dist-packages (from keras-applications<=1.0.8,>=1.0.7->image-classifiers) (3.1.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.8/dist-packages (from keras-applications<=1.0.8,>=1.0.7->image-classifiers) (1.21.6)
#                Layer Name |   MACs
# ****************************************************************************************************
#                      data | 0.0000
#                   bn_data | 0.0000
#        zero_padding2d_162 | 0.0000
#                     conv0 | 3396288.0000
#                       bn0 | 0.0000
#                     relu0 | 0.0000
#        zero_padding2d_163 | 0.0000
#                  pooling0 | 0.0000
#          stage1_unit1_bn1 | 0.0000
#        stage1_unit1_relu1 | 0.0000
#        zero_padding2d_164 | 0.0000
#        stage1_unit1_conv1 | 3686400.0000
#          stage1_unit1_bn2 | 0.0000
#        stage1_unit1_relu2 | 0.0000
#        zero_padding2d_165 | 0.0000
#        stage1_unit1_conv2 | 3686400.0000
#           stage1_unit1_sc | 262144.0000
#                    add_72 | 0.0000
#          stage1_unit2_bn1 | 0.0000
#        stage1_unit2_relu1 | 0.0000
#        zero_padding2d_166 | 0.0000
#        stage1_unit2_conv1 | 3686400.0000
#          stage1_unit2_bn2 | 0.0000
#        stage1_unit2_relu2 | 0.0000
#        zero_padding2d_167 | 0.0000
#        stage1_unit2_conv2 | 3686400.0000
#                    add_73 | 0.0000
#          stage2_unit1_bn1 | 0.0000
#        stage2_unit1_relu1 | 0.0000
#        zero_padding2d_168 | 0.0000
#        stage2_unit1_conv1 | 1843200.0000
#          stage2_unit1_bn2 | 0.0000
#        stage2_unit1_relu2 | 0.0000
#        zero_padding2d_169 | 0.0000
#        stage2_unit1_conv2 | 5308416.0000
#           stage2_unit1_sc | 131072.0000
#                    add_74 | 0.0000
#          stage2_unit2_bn1 | 0.0000
#        stage2_unit2_relu1 | 0.0000
#        zero_padding2d_170 | 0.0000
#        stage2_unit2_conv1 | 5308416.0000
#          stage2_unit2_bn2 | 0.0000
#        stage2_unit2_relu2 | 0.0000
#        zero_padding2d_171 | 0.0000
#        stage2_unit2_conv2 | 5308416.0000
#                    add_75 | 0.0000
#          stage3_unit1_bn1 | 0.0000
#        stage3_unit1_relu1 | 0.0000
#        zero_padding2d_172 | 0.0000
#        stage3_unit1_conv1 | 2654208.0000
#          stage3_unit1_bn2 | 0.0000
#        stage3_unit1_relu2 | 0.0000
#        zero_padding2d_173 | 0.0000
#        stage3_unit1_conv2 | 9437184.0000
#           stage3_unit1_sc | 131072.0000
#                    add_76 | 0.0000
#          stage3_unit2_bn1 | 0.0000
#        stage3_unit2_relu1 | 0.0000
#        zero_padding2d_174 | 0.0000
#        stage3_unit2_conv1 | 9437184.0000
#          stage3_unit2_bn2 | 0.0000
#        stage3_unit2_relu2 | 0.0000
#        zero_padding2d_175 | 0.0000
#        stage3_unit2_conv2 | 9437184.0000
#                    add_77 | 0.0000
#          stage4_unit1_bn1 | 0.0000
#        stage4_unit1_relu1 | 0.0000
#        zero_padding2d_176 | 0.0000
#        stage4_unit1_conv1 | 4718592.0000
#          stage4_unit1_bn2 | 0.0000
#        stage4_unit1_relu2 | 0.0000
#        zero_padding2d_177 | 0.0000
#        stage4_unit1_conv2 | 21233664.0000
#           stage4_unit1_sc | 131072.0000
#                    add_78 | 0.0000
#          stage4_unit2_bn1 | 0.0000
#        stage4_unit2_relu1 | 0.0000
#        zero_padding2d_178 | 0.0000
#        stage4_unit2_conv1 | 21233664.0000
#          stage4_unit2_bn2 | 0.0000
#        stage4_unit2_relu2 | 0.0000
#        zero_padding2d_179 | 0.0000
#        stage4_unit2_conv2 | 21233664.0000
#                    add_79 | 0.0000
#                       bn1 | 0.0000
#                     relu1 | 0.0000
#
# Total MACs operations in the complete model: 135951040.00000000
#
# 32/32 [==============================] - 10s 110ms/step - loss: 13.2545 - accuracy: 0.0025 - model_9_data: 0.9966 - model_9_bn_data: 0.9966 - model_9_zero_padding2d_162: 0.7067 - model_9_conv0: 0.9997 - model_9_bn0: 0.9997 - model_9_relu0: 0.4587 - model_9_zero_padding2d_163: 0.3624 - model_9_pooling0: 0.6144 - model_9_stage1_unit1_bn1: 0.6144 - model_9_stage1_unit1_relu1: 0.6144 - model_9_zero_padding2d_164: 0.3932 - model_9_stage1_unit1_conv1: 1.0000 - model_9_stage1_unit1_bn2: 1.0000 - model_9_stage1_unit1_relu2: 0.4659 - model_9_zero_padding2d_165: 0.2981 - model_9_stage1_unit1_conv2: 1.0000 - model_9_stage1_unit1_sc: 0.9999 - model_9_add_72: 1.0000 - model_9_stage1_unit2_bn1: 1.0000 - model_9_stage1_unit2_relu1: 0.5557 - model_9_zero_padding2d_166: 0.3556 - model_9_stage1_unit2_conv1: 1.0000 - model_9_stage1_unit2_bn2: 1.0000 - model_9_stage1_unit2_relu2: 0.4565 - model_9_zero_padding2d_167: 0.2922 - model_9_stage1_unit2_conv2: 1.0000 - model_9_add_73: 1.0000 - model_9_stage2_unit1_bn1: 1.0000 - model_9_stage2_unit1_relu1: 0.5506 - model_9_zero_padding2d_168: 0.3524 - model_9_stage2_unit1_conv1: 1.0000 - model_9_stage2_unit1_bn2: 1.0000 - model_9_stage2_unit1_relu2: 0.4941 - model_9_zero_padding2d_169: 0.2196 - model_9_stage2_unit1_conv2: 1.0000 - model_9_stage2_unit1_sc: 1.0000 - model_9_add_74: 1.0000 - model_9_stage2_unit2_bn1: 1.0000 - model_9_stage2_unit2_relu1: 0.5099 - model_9_zero_padding2d_170: 0.2266 - model_9_stage2_unit2_conv1: 1.0000 - model_9_stage2_unit2_bn2: 1.0000 - model_9_stage2_unit2_relu2: 0.4771 - model_9_zero_padding2d_171: 0.2121 - model_9_stage2_unit2_conv2: 1.0000 - model_9_add_75: 1.0000 - model_9_stage3_unit1_bn1: 1.0000 - model_9_stage3_unit1_relu1: 0.5248 - model_9_zero_padding2d_172: 0.2333 - model_9_stage3_unit1_conv1: 1.0000 - model_9_stage3_unit1_bn2: 1.0000 - model_9_stage3_unit1_relu2: 0.4788 - model_9_zero_padding2d_173: 0.1197 - model_9_stage3_unit1_conv2: 1.0000 - model_9_stage3_unit1_sc: 1.0000 - model_9_add_76: 1.0000 - model_9_stage3_unit2_bn1: 1.0000 - model_9_stage3_unit2_relu1: 0.4993 - model_9_zero_padding2d_174: 0.1248 - model_9_stage3_unit2_conv1: 1.0000 - model_9_stage3_unit2_bn2: 1.0000 - model_9_stage3_unit2_relu2: 0.4978 - model_9_zero_padding2d_175: 0.1245 - model_9_stage3_unit2_conv2: 1.0000 - model_9_add_77: 1.0000 - model_9_stage4_unit1_bn1: 1.0000 - model_9_stage4_unit1_relu1: 0.4914 - model_9_zero_padding2d_176: 0.1228 - model_9_stage4_unit1_conv1: 1.0000 - model_9_stage4_unit1_bn2: 1.0000 - model_9_stage4_unit1_relu2: 0.4931 - model_9_zero_padding2d_177: 0.0548 - model_9_stage4_unit1_conv2: 1.0000 - model_9_stage4_unit1_sc: 1.0000 - model_9_add_78: 1.0000 - model_9_stage4_unit2_bn1: 1.0000 - model_9_stage4_unit2_relu1: 0.4660 - model_9_zero_padding2d_178: 0.0518 - model_9_stage4_unit2_conv1: 1.0000 - model_9_stage4_unit2_bn2: 1.0000 - model_9_stage4_unit2_relu2: 0.5180 - model_9_zero_padding2d_179: 0.0576 - model_9_stage4_unit2_conv2: 1.0000 - model_9_add_79: 1.0000 - model_9_bn1: 1.0000 - model_9_relu1: 0.4626
#                   Metrics and Layer Name | Effective data communicated
# ******************************************************************************************************************************************************
#                                     loss | 13.2545
#                                 accuracy | 0.0025
#                             model_9_data | 0.9966
#                          model_9_bn_data | 0.9966
#               model_9_zero_padding2d_162 | 0.7067
#                            model_9_conv0 | 0.9997
#                              model_9_bn0 | 0.9997
#                            model_9_relu0 | 0.4587
#               model_9_zero_padding2d_163 | 0.3624
#                         model_9_pooling0 | 0.6144
#                 model_9_stage1_unit1_bn1 | 0.6144
#               model_9_stage1_unit1_relu1 | 0.6144
#               model_9_zero_padding2d_164 | 0.3932
#               model_9_stage1_unit1_conv1 | 1.0000
#                 model_9_stage1_unit1_bn2 | 1.0000
#               model_9_stage1_unit1_relu2 | 0.4659
#               model_9_zero_padding2d_165 | 0.2981
#               model_9_stage1_unit1_conv2 | 1.0000
#                  model_9_stage1_unit1_sc | 0.9999
#                           model_9_add_72 | 1.0000
#                 model_9_stage1_unit2_bn1 | 1.0000
#               model_9_stage1_unit2_relu1 | 0.5557
#               model_9_zero_padding2d_166 | 0.3556
#               model_9_stage1_unit2_conv1 | 1.0000
#                 model_9_stage1_unit2_bn2 | 1.0000
#               model_9_stage1_unit2_relu2 | 0.4565
#               model_9_zero_padding2d_167 | 0.2922
#               model_9_stage1_unit2_conv2 | 1.0000
#                           model_9_add_73 | 1.0000
#                 model_9_stage2_unit1_bn1 | 1.0000
#               model_9_stage2_unit1_relu1 | 0.5506
#               model_9_zero_padding2d_168 | 0.3524
#               model_9_stage2_unit1_conv1 | 1.0000
#                 model_9_stage2_unit1_bn2 | 1.0000
#               model_9_stage2_unit1_relu2 | 0.4941
#               model_9_zero_padding2d_169 | 0.2196
#               model_9_stage2_unit1_conv2 | 1.0000
#                  model_9_stage2_unit1_sc | 1.0000
#                           model_9_add_74 | 1.0000
#                 model_9_stage2_unit2_bn1 | 1.0000
#               model_9_stage2_unit2_relu1 | 0.5099
#               model_9_zero_padding2d_170 | 0.2266
#               model_9_stage2_unit2_conv1 | 1.0000
#                 model_9_stage2_unit2_bn2 | 1.0000
#               model_9_stage2_unit2_relu2 | 0.4771
#               model_9_zero_padding2d_171 | 0.2121
#               model_9_stage2_unit2_conv2 | 1.0000
#                           model_9_add_75 | 1.0000
#                 model_9_stage3_unit1_bn1 | 1.0000
#               model_9_stage3_unit1_relu1 | 0.5248
#               model_9_zero_padding2d_172 | 0.2333
#               model_9_stage3_unit1_conv1 | 1.0000
#                 model_9_stage3_unit1_bn2 | 1.0000
#               model_9_stage3_unit1_relu2 | 0.4788
#               model_9_zero_padding2d_173 | 0.1197
#               model_9_stage3_unit1_conv2 | 1.0000
#                  model_9_stage3_unit1_sc | 1.0000
#                           model_9_add_76 | 1.0000
#                 model_9_stage3_unit2_bn1 | 1.0000
#               model_9_stage3_unit2_relu1 | 0.4993
#               model_9_zero_padding2d_174 | 0.1248
#               model_9_stage3_unit2_conv1 | 1.0000
#                 model_9_stage3_unit2_bn2 | 1.0000
#               model_9_stage3_unit2_relu2 | 0.4978
#               model_9_zero_padding2d_175 | 0.1245
#               model_9_stage3_unit2_conv2 | 1.0000
#                           model_9_add_77 | 1.0000
#                 model_9_stage4_unit1_bn1 | 1.0000
#               model_9_stage4_unit1_relu1 | 0.4914
#               model_9_zero_padding2d_176 | 0.1228
#               model_9_stage4_unit1_conv1 | 1.0000
#                 model_9_stage4_unit1_bn2 | 1.0000
#               model_9_stage4_unit1_relu2 | 0.4931
#               model_9_zero_padding2d_177 | 0.0548
#               model_9_stage4_unit1_conv2 | 1.0000
#                  model_9_stage4_unit1_sc | 1.0000
#                           model_9_add_78 | 1.0000
#                 model_9_stage4_unit2_bn1 | 1.0000
#               model_9_stage4_unit2_relu1 | 0.4660
#               model_9_zero_padding2d_178 | 0.0518
#               model_9_stage4_unit2_conv1 | 1.0000
#                 model_9_stage4_unit2_bn2 | 1.0000
#               model_9_stage4_unit2_relu2 | 0.5180
#               model_9_zero_padding2d_179 | 0.0576
#               model_9_stage4_unit2_conv2 | 1.0000
#                           model_9_add_79 | 1.0000
#                              model_9_bn1 | 1.0000
#                            model_9_relu1 | 0.4626

# %%
# Calculations for Resnet50 CNN model
from tensorflow.keras.applications.resnet50 import ResNet50
model_Resnet50 = ResNet50(include_top=False,
                        weights='imagenet',
                        input_shape=(32, 32, 3),
                        pooling=None)
MAC_summary(model_Resnet50)
data_summary(model_Resnet50)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step
#                Layer Name |   MACs
# ****************************************************************************************************
#                   input_1 | 0.0000
#                 conv1_pad | 0.0000
#                conv1_conv | 3396288.0000
#                  conv1_bn | 0.0000
#                conv1_relu | 0.0000
#                 pool1_pad | 0.0000
#                pool1_pool | 0.0000
#       conv2_block1_1_conv | 262144.0000
#         conv2_block1_1_bn | 0.0000
#       conv2_block1_1_relu | 0.0000
#       conv2_block1_2_conv | 2359296.0000
#         conv2_block1_2_bn | 0.0000
#       conv2_block1_2_relu | 0.0000
#       conv2_block1_0_conv | 1048576.0000
#       conv2_block1_3_conv | 1048576.0000
#         conv2_block1_0_bn | 0.0000
#         conv2_block1_3_bn | 0.0000
#          conv2_block1_add | 0.0000
#          conv2_block1_out | 0.0000
#       conv2_block2_1_conv | 1048576.0000
#         conv2_block2_1_bn | 0.0000
#       conv2_block2_1_relu | 0.0000
#       conv2_block2_2_conv | 2359296.0000
#         conv2_block2_2_bn | 0.0000
#       conv2_block2_2_relu | 0.0000
#       conv2_block2_3_conv | 1048576.0000
#         conv2_block2_3_bn | 0.0000
#          conv2_block2_add | 0.0000
#          conv2_block2_out | 0.0000
#       conv2_block3_1_conv | 1048576.0000
#         conv2_block3_1_bn | 0.0000
#       conv2_block3_1_relu | 0.0000
#       conv2_block3_2_conv | 2359296.0000
#         conv2_block3_2_bn | 0.0000
#       conv2_block3_2_relu | 0.0000
#       conv2_block3_3_conv | 1048576.0000
#         conv2_block3_3_bn | 0.0000
#          conv2_block3_add | 0.0000
#          conv2_block3_out | 0.0000
#       conv3_block1_1_conv | 524288.0000
#         conv3_block1_1_bn | 0.0000
#       conv3_block1_1_relu | 0.0000
#       conv3_block1_2_conv | 2359296.0000
#         conv3_block1_2_bn | 0.0000
#       conv3_block1_2_relu | 0.0000
#       conv3_block1_0_conv | 2097152.0000
#       conv3_block1_3_conv | 1048576.0000
#         conv3_block1_0_bn | 0.0000
#         conv3_block1_3_bn | 0.0000
#          conv3_block1_add | 0.0000
#          conv3_block1_out | 0.0000
#       conv3_block2_1_conv | 1048576.0000
#         conv3_block2_1_bn | 0.0000
#       conv3_block2_1_relu | 0.0000
#       conv3_block2_2_conv | 2359296.0000
#         conv3_block2_2_bn | 0.0000
#       conv3_block2_2_relu | 0.0000
#       conv3_block2_3_conv | 1048576.0000
#         conv3_block2_3_bn | 0.0000
#          conv3_block2_add | 0.0000
#          conv3_block2_out | 0.0000
#       conv3_block3_1_conv | 1048576.0000
#         conv3_block3_1_bn | 0.0000
#       conv3_block3_1_relu | 0.0000
#       conv3_block3_2_conv | 2359296.0000
#         conv3_block3_2_bn | 0.0000
#       conv3_block3_2_relu | 0.0000
#       conv3_block3_3_conv | 1048576.0000
#         conv3_block3_3_bn | 0.0000
#          conv3_block3_add | 0.0000
#          conv3_block3_out | 0.0000
#       conv3_block4_1_conv | 1048576.0000
#         conv3_block4_1_bn | 0.0000
#       conv3_block4_1_relu | 0.0000
#       conv3_block4_2_conv | 2359296.0000
#         conv3_block4_2_bn | 0.0000
#       conv3_block4_2_relu | 0.0000
#       conv3_block4_3_conv | 1048576.0000
#         conv3_block4_3_bn | 0.0000
#          conv3_block4_add | 0.0000
#          conv3_block4_out | 0.0000
#       conv4_block1_1_conv | 524288.0000
#         conv4_block1_1_bn | 0.0000
#       conv4_block1_1_relu | 0.0000
#       conv4_block1_2_conv | 2359296.0000
#         conv4_block1_2_bn | 0.0000
#       conv4_block1_2_relu | 0.0000
#       conv4_block1_0_conv | 2097152.0000
#       conv4_block1_3_conv | 1048576.0000
#         conv4_block1_0_bn | 0.0000
#         conv4_block1_3_bn | 0.0000
#          conv4_block1_add | 0.0000
#          conv4_block1_out | 0.0000
#       conv4_block2_1_conv | 1048576.0000
#         conv4_block2_1_bn | 0.0000
#       conv4_block2_1_relu | 0.0000
#       conv4_block2_2_conv | 2359296.0000
#         conv4_block2_2_bn | 0.0000
#       conv4_block2_2_relu | 0.0000
#       conv4_block2_3_conv | 1048576.0000
#         conv4_block2_3_bn | 0.0000
#          conv4_block2_add | 0.0000
#          conv4_block2_out | 0.0000
#       conv4_block3_1_conv | 1048576.0000
#         conv4_block3_1_bn | 0.0000
#       conv4_block3_1_relu | 0.0000
#       conv4_block3_2_conv | 2359296.0000
#         conv4_block3_2_bn | 0.0000
#       conv4_block3_2_relu | 0.0000
#       conv4_block3_3_conv | 1048576.0000
#         conv4_block3_3_bn | 0.0000
#          conv4_block3_add | 0.0000
#          conv4_block3_out | 0.0000
#       conv4_block4_1_conv | 1048576.0000
#         conv4_block4_1_bn | 0.0000
#       conv4_block4_1_relu | 0.0000
#       conv4_block4_2_conv | 2359296.0000
#         conv4_block4_2_bn | 0.0000
#       conv4_block4_2_relu | 0.0000
#       conv4_block4_3_conv | 1048576.0000
#         conv4_block4_3_bn | 0.0000
#          conv4_block4_add | 0.0000
#          conv4_block4_out | 0.0000
#       conv4_block5_1_conv | 1048576.0000
#         conv4_block5_1_bn | 0.0000
#       conv4_block5_1_relu | 0.0000
#       conv4_block5_2_conv | 2359296.0000
#         conv4_block5_2_bn | 0.0000
#       conv4_block5_2_relu | 0.0000
#       conv4_block5_3_conv | 1048576.0000
#         conv4_block5_3_bn | 0.0000
#          conv4_block5_add | 0.0000
#          conv4_block5_out | 0.0000
#       conv4_block6_1_conv | 1048576.0000
#         conv4_block6_1_bn | 0.0000
#       conv4_block6_1_relu | 0.0000
#       conv4_block6_2_conv | 2359296.0000
#         conv4_block6_2_bn | 0.0000
#       conv4_block6_2_relu | 0.0000
#       conv4_block6_3_conv | 1048576.0000
#         conv4_block6_3_bn | 0.0000
#          conv4_block6_add | 0.0000
#          conv4_block6_out | 0.0000
#       conv5_block1_1_conv | 524288.0000
#         conv5_block1_1_bn | 0.0000
#       conv5_block1_1_relu | 0.0000
#       conv5_block1_2_conv | 2359296.0000
#         conv5_block1_2_bn | 0.0000
#       conv5_block1_2_relu | 0.0000
#       conv5_block1_0_conv | 2097152.0000
#       conv5_block1_3_conv | 1048576.0000
#         conv5_block1_0_bn | 0.0000
#         conv5_block1_3_bn | 0.0000
#          conv5_block1_add | 0.0000
#          conv5_block1_out | 0.0000
#       conv5_block2_1_conv | 1048576.0000
#         conv5_block2_1_bn | 0.0000
#       conv5_block2_1_relu | 0.0000
#       conv5_block2_2_conv | 2359296.0000
#         conv5_block2_2_bn | 0.0000
#       conv5_block2_2_relu | 0.0000
#       conv5_block2_3_conv | 1048576.0000
#         conv5_block2_3_bn | 0.0000
#          conv5_block2_add | 0.0000
#          conv5_block2_out | 0.0000
#       conv5_block3_1_conv | 1048576.0000
#         conv5_block3_1_bn | 0.0000
#       conv5_block3_1_relu | 0.0000
#       conv5_block3_2_conv | 2359296.0000
#         conv5_block3_2_bn | 0.0000
#       conv5_block3_2_relu | 0.0000
#       conv5_block3_3_conv | 1048576.0000
#         conv5_block3_3_bn | 0.0000
#          conv5_block3_add | 0.0000
#          conv5_block3_out | 0.0000
#
# Total MACs operations in the complete model: 79680192.00000000
#
# 32/32 [==============================] - 24s 293ms/step - loss: 10.9389 - accuracy: 0.0000e+00 - resnet50_input_1: 0.9966 - resnet50_conv1_pad: 0.7067 - resnet50_conv1_conv: 0.9997 - resnet50_conv1_bn: 0.9997 - resnet50_conv1_relu: 0.4901 - resnet50_pool1_pad: 0.3872 - resnet50_pool1_pool: 0.6546 - resnet50_conv2_block1_1_conv: 0.9999 - resnet50_conv2_block1_1_bn: 0.9999 - resnet50_conv2_block1_1_relu: 0.4509 - resnet50_conv2_block1_2_conv: 1.0000 - resnet50_conv2_block1_2_bn: 1.0000 - resnet50_conv2_block1_2_relu: 0.4651 - resnet50_conv2_block1_0_conv: 0.9999 - resnet50_conv2_block1_3_conv: 1.0000 - resnet50_conv2_block1_0_bn: 0.9999 - resnet50_conv2_block1_3_bn: 1.0000 - resnet50_conv2_block1_add: 1.0000 - resnet50_conv2_block1_out: 0.5614 - resnet50_conv2_block2_1_conv: 1.0000 - resnet50_conv2_block2_1_bn: 1.0000 - resnet50_conv2_block2_1_relu: 0.4874 - resnet50_conv2_block2_2_conv: 1.0000 - resnet50_conv2_block2_2_bn: 1.0000 - resnet50_conv2_block2_2_relu: 0.5279 - resnet50_conv2_block2_3_conv: 1.0000 - resnet50_conv2_block2_3_bn: 1.0000 - resnet50_conv2_block2_add: 1.0000 - resnet50_conv2_block2_out: 0.7442 - resnet50_conv2_block3_1_conv: 1.0000 - resnet50_conv2_block3_1_bn: 1.0000 - resnet50_conv2_block3_1_relu: 0.5288 - resnet50_conv2_block3_2_conv: 1.0000 - resnet50_conv2_block3_2_bn: 1.0000 - resnet50_conv2_block3_2_relu: 0.5341 - resnet50_conv2_block3_3_conv: 1.0000 - resnet50_conv2_block3_3_bn: 1.0000 - resnet50_conv2_block3_add: 1.0000 - resnet50_conv2_block3_out: 0.7531 - resnet50_conv3_block1_1_conv: 1.0000 - resnet50_conv3_block1_1_bn: 1.0000 - resnet50_conv3_block1_1_relu: 0.5482 - resnet50_conv3_block1_2_conv: 1.0000 - resnet50_conv3_block1_2_bn: 1.0000 - resnet50_conv3_block1_2_relu: 0.4676 - resnet50_conv3_block1_0_conv: 1.0000 - resnet50_conv3_block1_3_conv: 1.0000 - resnet50_conv3_block1_0_bn: 1.0000 - resnet50_conv3_block1_3_bn: 1.0000 - resnet50_conv3_block1_add: 1.0000 - resnet50_conv3_block1_out: 0.5153 - resnet50_conv3_block2_1_conv: 1.0000 - resnet50_conv3_block2_1_bn: 1.0000 - resnet50_conv3_block2_1_relu: 0.4870 - resnet50_conv3_block2_2_conv: 1.0000 - resnet50_conv3_block2_2_bn: 1.0000 - resnet50_conv3_block2_2_relu: 0.5084 - resnet50_conv3_block2_3_conv: 1.0000 - resnet50_conv3_block2_3_bn: 1.0000 - resnet50_conv3_block2_add: 1.0000 - resnet50_conv3_block2_out: 0.7190 - resnet50_conv3_block3_1_conv: 1.0000 - resnet50_conv3_block3_1_bn: 1.0000 - resnet50_conv3_block3_1_relu: 0.5633 - resnet50_conv3_block3_2_conv: 1.0000 - resnet50_conv3_block3_2_bn: 1.0000 - resnet50_conv3_block3_2_relu: 0.4507 - resnet50_conv3_block3_3_conv: 1.0000 - resnet50_conv3_block3_3_bn: 1.0000 - resnet50_conv3_block3_add: 1.0000 - resnet50_conv3_block3_out: 0.7815 - resnet50_conv3_block4_1_conv: 1.0000 - resnet50_conv3_block4_1_bn: 1.0000 - resnet50_conv3_block4_1_relu: 0.4899 - resnet50_conv3_block4_2_conv: 1.0000 - resnet50_conv3_block4_2_bn: 1.0000 - resnet50_conv3_block4_2_relu: 0.5333 - resnet50_conv3_block4_3_conv: 1.0000 - resnet50_conv3_block4_3_bn: 1.0000 - resnet50_conv3_block4_add: 1.0000 - resnet50_conv3_block4_out: 0.7862 - resnet50_conv4_block1_1_conv: 1.0000 - resnet50_conv4_block1_1_bn: 1.0000 - resnet50_conv4_block1_1_relu: 0.4843 - resnet50_conv4_block1_2_conv: 1.0000 - resnet50_conv4_block1_2_bn: 1.0000 - resnet50_conv4_block1_2_relu: 0.5090 - resnet50_conv4_block1_0_conv: 1.0000 - resnet50_conv4_block1_3_conv: 1.0000 - resnet50_conv4_block1_0_bn: 1.0000 - resnet50_conv4_block1_3_bn: 1.0000 - resnet50_conv4_block1_add: 1.0000 - resnet50_conv4_block1_out: 0.4831 - resnet50_conv4_block2_1_conv: 1.0000 - resnet50_conv4_block2_1_bn: 1.0000 - resnet50_conv4_block2_1_relu: 0.4894 - resnet50_conv4_block2_2_conv: 1.0000 - resnet50_conv4_block2_2_bn: 1.0000 - resnet50_conv4_block2_2_relu: 0.5294 - resnet50_conv4_block2_3_conv: 1.0000 - resnet50_conv4_block2_3_bn: 1.0000 - resnet50_conv4_block2_add: 1.0000 - resnet50_conv4_block2_out: 0.7005 - resnet50_conv4_block3_1_conv: 1.0000 - resnet50_conv4_block3_1_bn: 1.0 ...
#                   Metrics and Layer Name | Effective data communicated
# ******************************************************************************************************************************************************
#                                     loss | 10.9389
#                                 accuracy | 0.0000
#                         resnet50_input_1 | 0.9966
#                       resnet50_conv1_pad | 0.7067
#                      resnet50_conv1_conv | 0.9997
#                        resnet50_conv1_bn | 0.9997
#                      resnet50_conv1_relu | 0.4901
#                       resnet50_pool1_pad | 0.3872
#                      resnet50_pool1_pool | 0.6546
#             resnet50_conv2_block1_1_conv | 0.9999
#               resnet50_conv2_block1_1_bn | 0.9999
#             resnet50_conv2_block1_1_relu | 0.4509
#             resnet50_conv2_block1_2_conv | 1.0000
#               resnet50_conv2_block1_2_bn | 1.0000
#             resnet50_conv2_block1_2_relu | 0.4651
#             resnet50_conv2_block1_0_conv | 0.9999
#             resnet50_conv2_block1_3_conv | 1.0000
#               resnet50_conv2_block1_0_bn | 0.9999
#               resnet50_conv2_block1_3_bn | 1.0000
#                resnet50_conv2_block1_add | 1.0000
#                resnet50_conv2_block1_out | 0.5614
#             resnet50_conv2_block2_1_conv | 1.0000
#               resnet50_conv2_block2_1_bn | 1.0000
#             resnet50_conv2_block2_1_relu | 0.4874
#             resnet50_conv2_block2_2_conv | 1.0000
#               resnet50_conv2_block2_2_bn | 1.0000
#             resnet50_conv2_block2_2_relu | 0.5279
#             resnet50_conv2_block2_3_conv | 1.0000
#               resnet50_conv2_block2_3_bn | 1.0000
#                resnet50_conv2_block2_add | 1.0000
#                resnet50_conv2_block2_out | 0.7442
#             resnet50_conv2_block3_1_conv | 1.0000
#               resnet50_conv2_block3_1_bn | 1.0000
#             resnet50_conv2_block3_1_relu | 0.5288
#             resnet50_conv2_block3_2_conv | 1.0000
#               resnet50_conv2_block3_2_bn | 1.0000
#             resnet50_conv2_block3_2_relu | 0.5341
#             resnet50_conv2_block3_3_conv | 1.0000
#               resnet50_conv2_block3_3_bn | 1.0000
#                resnet50_conv2_block3_add | 1.0000
#                resnet50_conv2_block3_out | 0.7531
#             resnet50_conv3_block1_1_conv | 1.0000
#               resnet50_conv3_block1_1_bn | 1.0000
#             resnet50_conv3_block1_1_relu | 0.5482
#             resnet50_conv3_block1_2_conv | 1.0000
#               resnet50_conv3_block1_2_bn | 1.0000
#             resnet50_conv3_block1_2_relu | 0.4676
#             resnet50_conv3_block1_0_conv | 1.0000
#             resnet50_conv3_block1_3_conv | 1.0000
#               resnet50_conv3_block1_0_bn | 1.0000
#               resnet50_conv3_block1_3_bn | 1.0000
#                resnet50_conv3_block1_add | 1.0000
#                resnet50_conv3_block1_out | 0.5153
#             resnet50_conv3_block2_1_conv | 1.0000
#               resnet50_conv3_block2_1_bn | 1.0000
#             resnet50_conv3_block2_1_relu | 0.4870
#             resnet50_conv3_block2_2_conv | 1.0000
#               resnet50_conv3_block2_2_bn | 1.0000
#             resnet50_conv3_block2_2_relu | 0.5084
#             resnet50_conv3_block2_3_conv | 1.0000
#               resnet50_conv3_block2_3_bn | 1.0000
#                resnet50_conv3_block2_add | 1.0000
#                resnet50_conv3_block2_out | 0.7190
#             resnet50_conv3_block3_1_conv | 1.0000
#               resnet50_conv3_block3_1_bn | 1.0000
#             resnet50_conv3_block3_1_relu | 0.5633
#             resnet50_conv3_block3_2_conv | 1.0000
#               resnet50_conv3_block3_2_bn | 1.0000
#             resnet50_conv3_block3_2_relu | 0.4507
#             resnet50_conv3_block3_3_conv | 1.0000
#               resnet50_conv3_block3_3_bn | 1.0000
#                resnet50_conv3_block3_add | 1.0000
#                resnet50_conv3_block3_out | 0.7815
#             resnet50_conv3_block4_1_conv | 1.0000
#               resnet50_conv3_block4_1_bn | 1.0000
#             resnet50_conv3_block4_1_relu | 0.4899
#             resnet50_conv3_block4_2_conv | 1.0000
#               resnet50_conv3_block4_2_bn | 1.0000
#             resnet50_conv3_block4_2_relu | 0.5333
#             resnet50_conv3_block4_3_conv | 1.0000
#               resnet50_conv3_block4_3_bn | 1.0000
#                resnet50_conv3_block4_add | 1.0000
#                resnet50_conv3_block4_out | 0.7862
#             resnet50_conv4_block1_1_conv | 1.0000
#               resnet50_conv4_block1_1_bn | 1.0000
#             resnet50_conv4_block1_1_relu | 0.4843
#             resnet50_conv4_block1_2_conv | 1.0000
#               resnet50_conv4_block1_2_bn | 1.0000
#             resnet50_conv4_block1_2_relu | 0.5090
#             resnet50_conv4_block1_0_conv | 1.0000
#             resnet50_conv4_block1_3_conv | 1.0000
#               resnet50_conv4_block1_0_bn | 1.0000
#               resnet50_conv4_block1_3_bn | 1.0000
#                resnet50_conv4_block1_add | 1.0000
#                resnet50_conv4_block1_out | 0.4831
#             resnet50_conv4_block2_1_conv | 1.0000
#               resnet50_conv4_block2_1_bn | 1.0000
#             resnet50_conv4_block2_1_relu | 0.4894
#             resnet50_conv4_block2_2_conv | 1.0000
#               resnet50_conv4_block2_2_bn | 1.0000
#             resnet50_conv4_block2_2_relu | 0.5294
#             resnet50_conv4_block2_3_conv | 1.0000
#               resnet50_conv4_block2_3_bn | 1.0000
#                resnet50_conv4_block2_add | 1.0000
#                resnet50_conv4_block2_out | 0.7005
#             resnet50_conv4_block3_1_conv | 1.0000
#               resnet50_conv4_block3_1_bn | 1.0000
#             resnet50_conv4_block3_1_relu | 0.5247
#             resnet50_conv4_block3_2_conv | 1.0000
#               resnet50_conv4_block3_2_bn | 1.0000
#             resnet50_conv4_block3_2_relu | 0.4735
#             resnet50_conv4_block3_3_conv | 1.0000
#               resnet50_conv4_block3_3_bn | 1.0000
#                resnet50_conv4_block3_add | 1.0000
#                resnet50_conv4_block3_out | 0.7769
#             resnet50_conv4_block4_1_conv | 1.0000
#               resnet50_conv4_block4_1_bn | 1.0000
#             resnet50_conv4_block4_1_relu | 0.4680
#             resnet50_conv4_block4_2_conv | 1.0000
#               resnet50_conv4_block4_2_bn | 1.0000
#             resnet50_conv4_block4_2_relu | 0.4820
#             resnet50_conv4_block4_3_conv | 1.0000
#               resnet50_conv4_block4_3_bn | 1.0000
#                resnet50_conv4_block4_add | 1.0000
#                resnet50_conv4_block4_out | 0.7928
#             resnet50_conv4_block5_1_conv | 1.0000
#               resnet50_conv4_block5_1_bn | 1.0000
#             resnet50_conv4_block5_1_relu | 0.5020
#             resnet50_conv4_block5_2_conv | 1.0000
#               resnet50_conv4_block5_2_bn | 1.0000
#             resnet50_conv4_block5_2_relu | 0.4951
#             resnet50_conv4_block5_3_conv | 1.0000
#               resnet50_conv4_block5_3_bn | 1.0000
#                resnet50_conv4_block5_add | 1.0000
#                resnet50_conv4_block5_out | 0.8173
#             resnet50_conv4_block6_1_conv | 1.0000
#               resnet50_conv4_block6_1_bn | 1.0000
#             resnet50_conv4_block6_1_relu | 0.4720
#             resnet50_conv4_block6_2_conv | 1.0000
#               resnet50_conv4_block6_2_bn | 1.0000
#             resnet50_conv4_block6_2_relu | 0.4998
#             resnet50_conv4_block6_3_conv | 1.0000
#               resnet50_conv4_block6_3_bn | 1.0000
#                resnet50_conv4_block6_add | 1.0000
#                resnet50_conv4_block6_out | 0.8250
#             resnet50_conv5_block1_1_conv | 1.0000
#               resnet50_conv5_block1_1_bn | 1.0000
#             resnet50_conv5_block1_1_relu | 0.4996
#             resnet50_conv5_block1_2_conv | 1.0000
#               resnet50_conv5_block1_2_bn | 1.0000
#             resnet50_conv5_block1_2_relu | 0.4928
#             resnet50_conv5_block1_0_conv | 1.0000
#             resnet50_conv5_block1_3_conv | 1.0000
#               resnet50_conv5_block1_0_bn | 1.0000
#               resnet50_conv5_block1_3_bn | 1.0000
#                resnet50_conv5_block1_add | 1.0000
#                resnet50_conv5_block1_out | 0.4878
#             resnet50_conv5_block2_1_conv | 1.0000
#               resnet50_conv5_block2_1_bn | 1.0000
#             resnet50_conv5_block2_1_relu | 0.5095
#             resnet50_conv5_block2_2_conv | 1.0000
#               resnet50_conv5_block2_2_bn | 1.0000
#             resnet50_conv5_block2_2_relu | 0.4874
#             resnet50_conv5_block2_3_conv | 1.0000
#               resnet50_conv5_block2_3_bn | 1.0000
#                resnet50_conv5_block2_add | 1.0000
#                resnet50_conv5_block2_out | 0.7267
#             resnet50_conv5_block3_1_conv | 1.0000
#               resnet50_conv5_block3_1_bn | 1.0000
#             resnet50_conv5_block3_1_relu | 0.5385
#             resnet50_conv5_block3_2_conv | 1.0000
#               resnet50_conv5_block3_2_bn | 1.0000
#             resnet50_conv5_block3_2_relu | 0.5013
#             resnet50_conv5_block3_3_conv | 1.0000
#               resnet50_conv5_block3_3_bn | 1.0000
#                resnet50_conv5_block3_add | 1.0000
#                resnet50_conv5_block3_out | 0.7890
